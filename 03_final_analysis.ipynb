# %%
import pandas as pd

data = {
    'Modelo': ['Logistic Regression', 'Random Forest'],
    'Accuracy': [0.89, 0.86],
    'Precision': [0.88, 0.85],
    'Recall': [0.90, 0.87],
    'F1-score': [0.89, 0.86]
}

df = pd.DataFrame(data)

df
# Out:
#                 Modelo  Accuracy  Precision  Recall  F1-score
# 0  Logistic Regression      0.89       0.88    0.90      0.89
# 1        Random Forest      0.86       0.85    0.87      0.86

# %%
import matplotlib.pyplot as plt

plt.bar(df['Modelo'], df['Accuracy'])

plt.title('Comparación Accuracy')

plt.ylabel('Accuracy')

plt.show()

# %% [markdown]
# # Conclusiones
#
# - Logistic Regression obtuvo mejores resultados.
# - TF-IDF mejoró el rendimiento.
# - NLP ayudó a limpiar y mejorar los datos.
